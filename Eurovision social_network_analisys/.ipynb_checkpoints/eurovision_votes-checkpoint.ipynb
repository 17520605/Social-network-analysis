# %% [markdown]
# # Phân tích khám phá Bộ dữ liệu phiếu bầu Eurovision 2018

# %% [markdown]
# Trong tập dữ liệu này, chúng em sẽ cố gắng khám phá và hình dung tập dữ liệu phiếu bầu eurovision 2018 như một mạng, sử dụng gói networkx

# %% [markdown]
# ## Cài Thư viện cần thiết để tiến hành phân tích

# %%
# %matplotlib inline
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from collections import Counter
import sys
import os
from __future__ import division
plt.rcParams["figure.figsize"] = (20,10)
from itertools import chain
import tqdm as tqdm
from colorthief import ColorThief
import xlsxwriter
warnings.filterwarnings('ignore')
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ## Link Trang chủ dữ liệu được phân tích

# %% [markdown]
# https://eurovision.tv/story/the-results-eurovision-2018-dive-into-numbers

# %% [markdown]
# ## Tiến hành đọc dữ liệu vào Jupyter NoteBook

# %%
votes_data = pd.read_excel('ESC2018_GF.xlsx',sheet_name='Combined result')

# %%
votes_data = pd.read_excel('ESC2018_GF.xlsx',sheet_name='Combined result')
print(votes_data.shape)
votes_data.head(10)
# Out:
# (26, 47)
#    Rank  Running order         Country  Total  Albania  Austria  Belarus  \
# 0     1             22          Israel    529        6       19        8
# 1     2             25          Cyprus    436       20        1       15
# 2     3              5         Austria    342        2        0       10
# 3     4             11         Germany    340       14       16        0
# 4     5             26           Italy    308       24       10        4
# 5     6             14  Czech Republic    281        1       15       11
# 6     7             20          Sweden    274        4        8        1
# 7     8              6         Estonia    245        4        2        0
# 8     9             15         Denmark    226        0        5       10
# 9    10             19         Moldova    209        2        0        6
#
#    Belgium  Croatia  Cyprus  ...  Hungary  Moldova  Armenia  Czech Republic  \
# 0       16       16      10  ...       16       22       18              22
# 1       11        8       0  ...        7       13       19               8
# 2       15        0       2  ...       11        3        7               5
# 3        7        3       3  ...        1        8        5               3
# 4        6       10      15  ...        6        8        3               2
# 5        8        9      13  ...        8        6       14               0
# 6        8        0      12  ...        1        0       12               8
# 7        0        0       5  ...        0       13        2               5
# 8        5        2       0  ...       24        0        0               7
# 9        0        8      10  ...        2        0       11               6
#
#    Georgia  Montenegro  Azerbaijan  San Marino  Italy  Australia
# 0       15           1          13          24      9         18
# 1       10           6          14           7      8          7
# 2        9           0           0           0      7          5
# 3        7           0           5          14     13         12
# 4        5          12           5          12      0          0
# 5        0           0           6          10      0          4
# 6       12           2           2           8      1         12
# 7       16           5           3           5     10          8
# 8        3           6           0           6     12         10
# 9        3           8          11           9     10          7
#
# [10 rows x 47 columns]

# %% [markdown]
# ### Triển khai đưa vào danh sách bình chọn cạnh

# %%
votes_melted = votes_data.melt(
    ['Rank','Running order','Country','Total'],
    var_name = 'Source Country',value_name='points')

# %%
votes_melted.head(10)
# Out:
#    Rank  Running order         Country  Total Source Country  points
# 0     1             22          Israel    529        Albania       6
# 1     2             25          Cyprus    436        Albania      20
# 2     3              5         Austria    342        Albania       2
# 3     4             11         Germany    340        Albania      14
# 4     5             26           Italy    308        Albania      24
# 5     6             14  Czech Republic    281        Albania       1
# 6     7             20          Sweden    274        Albania       4
# 7     8              6         Estonia    245        Albania       4
# 8     9             15         Denmark    226        Albania       0
# 9    10             19         Moldova    209        Albania       2

# %% [markdown]
# ### Xây dựng một biểu đồ networkx có trọng số, có định hướng từ edgelist trong votes_melted:

# %%
G = nx.from_pandas_edgelist(votes_melted, 
                            source='Source Country',
                            target='Country',
                            edge_attr='points',
                            create_using=nx.DiGraph())

# %% [markdown]
# ### Xuất ra dữ liệu cạnh

# %%
votes_melted.to_excel('ESC_Edges.xlsx')

# %%
print(nx.info(G))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 43
# Number of edges: 1118
# Average in degree:  26.0000
# Average out degree:  26.0000

# %% [markdown]
# ### Tiến hành loại bỏ những điểm bằng 0

# %%
Gsub = G.edge_subgraph([(e[0],e[1]) for e in G.edges(data=True) if e[2]['points']>0])

# %%
print(nx.info(Gsub))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 43
# Number of edges: 650
# Average in degree:  15.1163
# Average out degree:  15.1163

# %%
nx.draw_networkx(Gsub)

# %%
plt.hist(dict(Gsub.degree()).values())
# Out:
# (array([16.,  1.,  3.,  2.,  3.,  5.,  4.,  1.,  4.,  4.]),
#  array([13. , 17.5, 22. , 26.5, 31. , 35.5, 40. , 44.5, 49. , 53.5, 58. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Tuy nhiên điểm số mới là thứ quyết định sự thắng bại

# %%
h = plt.hist(dict(G.in_degree(weight='points')).values())

# %% [markdown]
# # DÙNG THUẬT TOÁN NETWORKX ĐỂ PHÂN TÍCH

# %% [markdown]
# ## Geometric centrality

# %%
deg_cen_points = dict(G.in_degree(weight='points'))
{k:deg_cen_points[k] for k in deg_cen_points if deg_cen_points[k]==max(deg_cen_points.values())}
# Out:
# {'Israel': 529}

# %%
closeness = dict(nx.closeness_centrality(Gsub))
{k:closeness[k] for k in closeness if closeness[k]==max(closeness.values())}
# Out:
# {'Cyprus': 1.0}

# %%
deg_centrality  = dict(nx.degree_centrality(Gsub))
{k:deg_centrality[k] for k in deg_centrality if deg_centrality[k]==max(deg_centrality.values())}
# Out:
# {'Israel': 1.380952380952381, 'Cyprus': 1.380952380952381}

# %%
deg_centrality  = dict(nx.out_degree_centrality(Gsub))
{k:deg_centrality[k] for k in deg_centrality if deg_centrality[k]==max(deg_centrality.values())}
# Out:
# {'France': 0.45238095238095233}

# %%
deg_centrality  = dict(nx.in_degree_centrality(Gsub))
{k:deg_centrality[k] for k in deg_centrality if deg_centrality[k]==max(deg_centrality.values())}
# Out:
# {'Cyprus': 1.0}

# %% [markdown]
# ## Spectral centrality measures

# %%
page_rank = dict(nx.pagerank(Gsub,weight='points'))
{k:page_rank[k] for k in page_rank if page_rank[k]==max(page_rank.values())}
# Out:
# {'Israel': 0.09068767468630147}

# %%
eigenvector = dict(nx.eigenvector_centrality(Gsub))
{k:eigenvector[k] for k in eigenvector if eigenvector[k]==max(eigenvector.values())}
# Out:
# {'Cyprus': 0.29155293399835497}

# %% [markdown]
# ## Meansures of centrality

# %% [markdown]
# thể hiện mức độ trung tâm của node, nếu node tương tác với càng nhiều node thì giá trị càng lớn

# %%
between = dict(nx.betweenness_centrality(Gsub))
{k:between[k] for k in between if between[k]==max(between.values())}
# Out:
# {'Israel': 0.02243762818675711}

# %%
clustering = dict(nx.clustering(Gsub))
{k:clustering[k] for k in clustering if clustering[k]}
# Out:
# {0: 1.0,
#  1: 1.0,
#  2: 1.0,
#  3: 1.0,
#  4: 0.6,
#  6: 0.6,
#  7: 1.0,
#  8: 1.0,
#  9: 1.0,
#  10: 1.0}

# %%
import functools
nodeMeasures = {
    'pagerank':nx.pagerank(Gsub,weight='points', max_iter=1000),
    'eigevector':nx.algorithms.centrality.eigenvector_centrality(Gsub,max_iter=1000),
    'degree':nx.algorithms.centrality.degree_centrality(Gsub),
    'betweenness':nx.algorithms.centrality.betweenness_centrality(Gsub),
    'closeness':nx.algorithms.centrality.closeness_centrality(Gsub),
};

nodeMeasures = [pd.DataFrame(nodeMeasures[v].items(), columns=['country',v]) for v in nodeMeasures]

nodeMeasures = functools.reduce(lambda  left,right: pd.merge(left,right,on='country', how='outer'), nodeMeasures)

def pond(x):
    x['pond'] = (1+x[['pagerank','degree','closeness','betweenness']]).cumprod()[-1]-1;
    return x;

nodeMeasures = nodeMeasures.apply(pond,axis=1)

nodeMeasures.corr().style.background_gradient().format("{:.1%}")
# Out:
# <style  type="text/css" >
#     #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col1 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col3 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col4 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col5 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col0 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col2 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col3 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col4 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col5 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col0 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col1 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col4 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col5 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row3_col0 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row3_col2 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row4_col1 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row4_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row4_col5 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row5_col0 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row5_col1 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row5_col2 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row5_col3 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row5_col4 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_3077f096_32ca_11eb_a5c6_9078419c3ec4row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >pagerank</th>        <th class="col_heading level0 col1" >eigevector</th>        <th class="col_heading level0 col2" >degree</th>        <th class="col_heading level0 col3" >betweenness</th>        <th class="col_heading level0 col4" >closeness</th>        <th class="col_heading level0 col5" >pond</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4level0_row0" class="row_heading level0 row0" >pagerank</th>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col0" class="data row0 col0" >100.0%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col1" class="data row0 col1" >93.6%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col2" class="data row0 col2" >94.6%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col3" class="data row0 col3" >93.1%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col4" class="data row0 col4" >86.6%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row0_col5" class="data row0 col5" >95.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4level0_row1" class="row_heading level0 row1" >eigevector</th>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col0" class="data row1 col0" >93.6%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col1" class="data row1 col1" >100.0%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col2" class="data row1 col2" >98.3%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col3" class="data row1 col3" >92.6%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col4" class="data row1 col4" >95.2%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row1_col5" class="data row1 col5" >98.5%</td>
#             </tr>
#             <tr>
#                         <th id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4level0_row2" class="row_heading level0 row2" >degree</th>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col0" class="data row2 col0" >94.6%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col1" class="data row2 col1" >98.3%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col2" class="data row2 col2" >100.0%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col3" class="data row2 col3" >95.5%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col4" class="data row2 col4" >94.8%</td>
#                         <td id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4row2_col5" class="data row2 col5" >99.5%</td>
#             </tr>
#             <tr>
#                         <th id="T_3077f096_32ca_11eb_a5c6_9078419c3ec4level0_row3" class="ro

# %%
nodeMeasures\
    .sort_values('pond',ascending=False).set_index('country').round(2)\
    .style.background_gradient(axis=0).format("{:.5}")
# Out:
# <style  type="text/css" >
#     #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row0_col1 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row0_col4 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row1_col0 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row1_col5 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row2_col0 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row2_col1 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row2_col2 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row2_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row2_col4 {
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row2_col5 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row3_col0 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row3_col1 {
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row3_col2 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row3_col4 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row3_col5 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row4_col0 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row4_col1 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row4_col2 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row4_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row4_col4 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row4_col5 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row5_col0 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row5_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row5_col2 {
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row5_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row5_col4 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row5_col5 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row6_col0 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row6_col1 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row6_col2 {
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row6_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row6_col4 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row6_col5 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row7_col0 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row7_col1 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row7_col2 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row7_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row7_col4 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row7_col5 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row8_col0 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row8_col1 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row8_col2 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row8_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row8_col4 {
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row8_col5 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row9_col0 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row9_col1 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row9_col2 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row9_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row9_col4 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_490b507f_32ca_11eb_a6a7_9078419c3ec4row9_col5 {
#             background-color:  #4a98c5;
#             color:  #000000;

# %% [markdown]
# # Tiến hành thêm lá cờ vào bộ dữ liệu để thiết kế

# %%
countries = pd.read_csv('countries.csv',index_col='Country',sep=",", encoding='cp1252')

# %%
countries.head()
# Out:
#                cc2   cc3  numeric  latitude  longitude
# Country
# Afghanistan     AF   AFG        4   33.0000       65.0
# Albania         AL   ALB        8   41.0000       20.0
# Algeria         DZ   DZA       12   28.0000        3.0
# American Samoa  AS   ASM       16  -14.3333     -170.0
# Andorra         AD   AND       20   42.5000        1.6

# %%
pos_geo = {  node: 
           ( max(-10,min(countries.loc[node]['longitude'],55)), # fixing scale
             max(countries.loc[node]['latitude'],25)) #fixing scale
               for node in G.nodes() }

# %%
pos_geo = {}
for node in G.nodes():
    pos_geo[node] = (
                    max(-10,min(countries.loc[node]['longitude'],55)), # fixing scale
                    max(countries.loc[node]['latitude'],25) #fixing scale
    )

# %% [markdown]
# # DÙNG THUẬT TOÁN VẼ KMEANS

# %%
shells = pd.merge(
    pd.DataFrame(pos_geo.items(), columns=['country','cluster']),
    pd.DataFrame(dict(Gsub.degree()).items(), columns=['country','degree'])
).sort_values(['cluster','degree'])['country'].values

# %%
influence = nx.pagerank(Gsub,weight='points')

# %%
flags = {}
flag_color = {}
for node in tqdm.tqdm_notebook(G.nodes()):
    flags[node] = 'flags/'+(countries.loc[node]['cc3']).lower().replace(' ','')+'.png'   
    flag_color[node] =  ColorThief(flags[node]).get_color(quality=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=43.0), HTML(value='')))

# %%
def RGB(red,green,blue): 
    return '#%02x%02x%02x' % (red,green,blue)

# %% [markdown]
# Tiến hành vẽ

# %%
ax=plt.gca()
fig=plt.gcf()
plt.axis('off')

pos = nx.layout.fruchterman_reingold_layout(G,k=1,weight = 'points',iterations=1000,scale = 2)
trans = ax.transData.transform
trans2 = fig.transFigure.inverted().transform

tick_params = {'top':'off', 'bottom':'off', 'left':'off', 'right':'off','labelleft':'off', 'labelbottom':'off'}
styles = ['dotted','dashdot','dashed','solid'] 

for e in G.edges(data=True):
    width = e[2]['points']/24 #normalize by max points
    style=styles[int(width*3)]
    if width>0.4: #filter small votes
        nx.draw_networkx_edges(G,pos,edgelist=[e],width=width,style=style, edge_color = RGB(*flag_color[e[0]]) )
for node in G.nodes():    
    imsize = max((0.3*G.in_degree(node,weight='points')/max(dict(G.in_degree(weight='points')).values()))**2,0.03)
    # size is proportional to the votes
    flag = mpl.image.imread(flags[node])
    
    (x,y) = pos[node]
    xx,yy = trans((x,y)) # figure coordinates
    xa,ya = trans2((xx,yy)) # axes coordinates
    
    country = plt.axes([xa-imsize/2.0,ya-imsize/2.0, imsize, imsize ])
    country.imshow(flag)
    country.set_aspect('equal')
    country.tick_params(**tick_params)
